# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import sklearn as sk

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
lr = LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
md = pd.read_csv('data1.csv')
print(md.head()) 
print(md.columns)
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
md = pd.read_csv('data1.csv')
j = md['Experience Years']
k = md['Salary']    
j_train, j_test, k_train, k_test = train_test_split(j, k, test_size=0.2, random_state=42)

# %%
lr = LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(j_train, k_train)
# Out:
# LinearRegression()

# %%
j_test = j_test.reshape(-1, 1)  
kpred = lr.predict(j_test)


print(j_test.shape)
# Out:
# (8, 1)

# %%
kpred
# Out:
# array([ 69052.39090243,  64348.37526617,  64348.37526617,  83164.43781119,
#         45532.31272116,  61525.96588442, 117033.35039221,  85046.04406569])

# %%
plt.scatter(j,k)

# %%
md = pd.read_csv('data1.csv')

# %%
md
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# ...

# %%
j = md.drop("Salary",axis=1)

# %%
k = md.Salary

# %%
k
# Out:
# 0      39343
# 1      42774
# 2      46205
# 3      37731
# 4      43525
# 5      39891
# 6      48266
# 7      56642
# 8      60150
# 9      54445
# 10     64445
# 11     60000
# 12     57189
# 13     60200
# 14     63218
# 15     55794
# 16     56957
# 17     57081
# 18     59095
# 19     61111
# 20     64500
# 21     67938
# 22     66029
# 23     83088
# 24     82200
# 25     81363
# 26     93940
# 27     91000
# 28     90000
# 29     91738
# 30     98273
# 31    101302
# 32    113812
# 33    111620
# 34    109431
# 35    105582
# 36    116969
# 37    112635
# 38    122391
# 39    121872
# Name: Salary, dtype: int64

# %%
md.isna().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
md.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
mean_absolute_error(kpred, k_test)
# Out:
# 6419.911069460598

# %%
import seaborn as sns

sns.regplot(x=j_test, y=k_test)
# Out:
# <Axes: ylabel='Salary'>

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.metrics import r2_score


r2 = r2_score(k_test, kpred)  
print(f"R² score: {r2}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 from sklearn.metrics import r2_score
# ----> 4 r2 = r2_score(k_test, kpred)
#       5 print(f"R² score: {r2}")
#
# NameError: name 'k_test' is not defined

# %%
k_pred = lr.predict(j_test)  
r2_score(k_pred, k_test)
# Out:
# 0.8810764392836917

# %%
kpred
# Out:
# array([ 69052.39090243,  64348.37526617,  64348.37526617,  83164.43781119,
#         45532.31272116,  61525.96588442, 117033.35039221,  85046.04406569])

# %%
k_test
# Out:
# 19     61111
# 16     56957
# 15     55794
# 26     93940
# 4      43525
# 12     57189
# 37    112635
# 27     91000
# Name: Salary, dtype: int64
